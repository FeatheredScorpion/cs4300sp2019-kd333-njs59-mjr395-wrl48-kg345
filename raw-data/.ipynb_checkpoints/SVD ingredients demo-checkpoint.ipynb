# %% [markdown]
# # Info/CS 4300: Language and Information
#
# ## SVD CLASS DEMO RECREATION FOR ROCKTAILS

# %%
from __future__ import print_function
import numpy as np
import json

# %% [markdown]
# ## Load the data

# %%
with open('../app/static/drinks.json', 'r') as infile:  
    jsonData = json.load(infile)
    drinklst = jsonData['drinks']
    
    for drink in drinklst:
        drinkByName[drink['name']] = drink
    
    for drink in drinklst:
        drink['ingredients'] = ' '.join(drink['ingredients'])
        drink['categories'] = ' '.join(drink['categories'])
#         drink['reviews'] = ' '.join(drink['reviews'])
    documents = [
        (x['name'],
         x['categories'],
         x['ingredients'])
                for x in drinklst]
    np.random.shuffle(documents)

# %%
print("Loaded {} documents".format(len(documents)))
print("Here is one of them:")
print(documents[0])
# Out:
# Loaded 2588 documents
# Here is one of them:
# ('Apple Pie', 'fall thanksgiving', '3 oz  Apple schnapps 1 oz  Cinnamon schnapps   Apple slice')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words = 'english', max_df = .7,
                            min_df = 75)
my_matrix = vectorizer.fit_transform([x[2] for x in documents]).transpose()
# Out:
# /Users/nate/Downloads/assignment5/venv/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1039: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
print(type(my_matrix))
print(my_matrix.shape)
# Out:
# <class 'scipy.sparse.csc.csc_matrix'>
# (91, 2588)

# %%
from scipy.sparse.linalg import svds
u, s, v_trans = svds(my_matrix, k=70)

# %%
print(u.shape)
print(s.shape)
print(v_trans.shape)
# Out:
# (91, 70)
# (70,)
# (70, 2588)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(s[::-1])
plt.xlabel("Singular value number")
plt.ylabel("Singular value")
plt.show()

# %%
words_compressed, _, docs_compressed = svds(my_matrix, k=40)
docs_compressed = docs_compressed.transpose()

# %%
print(words_compressed.shape)
print(docs_compressed.shape)
# Out:
# (91, 40)
# (2588, 40)

# %%
word_to_index = vectorizer.vocabulary_
index_to_word = {i:t for t,i in word_to_index.items()}
print(words_compressed.shape)
# Out:
# (91, 40)

# %%
#row normalize
from sklearn.preprocessing import normalize
words_compressed = normalize(words_compressed, axis = 1)

# %%
def closest_words(word_in, k = 10):
    if word_in not in word_to_index: return "Not in vocab."
    sims = words_compressed.dot(words_compressed[word_to_index[word_in],:])
    asort = np.argsort(-sims)[:k+1]
    return [(index_to_word[i],sims[i]/sims[asort[0]]) for i in asort[1:]]

# %%
closest_words("sour")
# Out:
# [('mix', 0.9358490140888571),
#  ('sweet', 0.8012120084832466),
#  ('taste', 0.18682388473241643),
#  ('slice', 0.15145119321328743),
#  ('amaretto', 0.14619059645344223),
#  ('apple', 0.14306194039270392),
#  ('wedge', 0.12561680978028542),
#  ('cinnamon', 0.11386501863030635),
#  ('tequila', 0.11088978822049139),
#  ('grenadine', 0.10769316990289265)]

# %%
print(list(word_to_index))
# Out:
# ['lime', 'dark', 'light', 'bitters', 'angostura', 'cranberry', 'tablespoons', 'schnapps', 'old', 'concentrate', 'optional', 'peach', 'cream', 'sugar', 'wine', 'sweet', 'sour', 'slice', 'grenadine', 'ice', 'juice', 'syrup', 'taste', 'fluid', 'amaretto', 'coconut', 'dry', 'crushed', 'flavored', 'whiskey', 'sec', 'boston', 'apple', 'cherry', 'creme', 'carbonated', 'cups', 'gin', 'tequila', 'cacao', 'white', 'bottle', 'teaspoon', 'pineapple', 'water', 'needed', 'ounce', 'frozen', 'fresh', 'grapefruit', 'rum', 'irish', 'vodka', 'ounces', 'mint', 'ginger', 'simple', 'blanco', 'liqueur', 'milk', 'vermouth', 'chilled', 'raspberry', 'mix', 'triple', 'cubes', 'garnish', 'lemon', 'jigger', 'powdered', 'wedge', 'tablespoon', 'bourbon', 'mr', 'twist', 'orange', '12', 'dash', 'vanilla', 'cup', 'egg', 'tsp', 'coffee', 'oz', 'salt', 'cinnamon', 'brandy', 'leaves', 'ground', 'soda', 'maraschino']

# %%
from sklearn.manifold import TSNE
tsne = TSNE(verbose=1)

# %%
print(docs_compressed.shape)
#we'll just take the first 5K documents, because TSNE is memory intensive!
subset = docs_compressed[:5000,:]
projected_docs = tsne.fit_transform(subset)
print(projected_docs.shape)
# Out:
# (2588, 40)
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2588
# [t-SNE] Computed conditional probabilities for sample 2000 / 2588
# [t-SNE] Computed conditional probabilities for sample 2588 / 2588
# [t-SNE] Mean sigma: 0.044817
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.414008
# [t-SNE] Error after 275 iterations: 1.414008
# (2588, 2)

# %%
plt.figure(figsize=(15,15))
plt.scatter(projected_docs[:,0],projected_docs[:,1])
plt.show()

# %%
from collections import Counter
t = [x[1] for x in documents]
cats = Counter(t)
print(cats)
# Out:
# Counter({'': 2121, 'winter': 64, 'afternoon': 32, 'night': 26, 'easter': 25, 'morning': 19, 'summer': 19, 'spring': 16, 'fall thanksgiving': 15, 'dinner party graduation': 14, 'st pattys': 13, 'winter st pattys': 13, 'halloween': 11, 'thanksgiving': 11, 'spring summer': 9, 'winter christmas': 9, 'fall': 9, 'dinner party': 8, 'winter morning': 8, 'party sports': 8, 'winter birthday': 8, 'morning graduation new years birthday': 7, 'winter thanksgiving': 7, 'spring morning': 6, 'winter night': 5, 'birthday': 5, 'spring sports': 4, 'spring summer afternoon': 4, 'sports': 4, 'graduation': 3, 'winter birthday christmas': 3, 'morning afternoon': 3, 'spring afternoon': 3, 'party': 3, 'fall winter': 2, 'spring easter': 2, 'spring summer sports': 2, 'winter halloween': 2, 'summer afternoon': 2, 'night easter': 2, 'afternoon party new years': 2, 'morning afternoon graduation': 2, 'graduation new years birthday': 2, 'morning graduation new years': 2, 'winter easter': 2, 'afternoon sports': 2, 'spring summer chinese new year': 1, 'morning easter': 1, 'morning st pattys': 1, 'spring afternoon party': 1, 'summer sports': 1, 'winter party thanksgiving halloween new years': 1, 'winter sports graduation': 1, 'summer morning afternoon': 1, 'morning afternoon sports': 1, 'spring halloween': 1, 'party new years': 1, 'morning night': 1, 'winter morning thanksgiving': 1, 'dinner party easter': 1, 'spring graduation': 1, 'summer afternoon party new years': 1, 'night easter birthday': 1, 'winter thanksgiving christmas': 1, 'winter graduation new years birthday': 1, 'halloween sports': 1, 'morning afternoon party thanksgiving graduation new years birthday': 1, 'morning graduation': 1, 'night dinner party graduation': 1, 'winter thanksgiving easter': 1, 'sports graduation': 1, 'fall winter night': 1, 'fall winter christmas': 1, 'winter morning night': 1, 'winter st pattys halloween': 1, 'fall winter thanksgiving': 1, 'summer morning graduation': 1, 'morning afternoon halloween': 1, 'party thanksgiving': 1, 'afternoon easter': 1, 'spring graduation new years': 1, 'spring afternoon halloween': 1, 'winter halloween birthday': 1, 'fall winter party thanksgiving new years': 1, 'summer dinner party graduation': 1, 'summer morning afternoon graduation new years birthday': 1, 'morning thanksgiving graduation new years birthday': 1, 'morning thanksgiving': 1, 'winter afternoon st pattys': 1, 'dinner party halloween easter': 1, 'winter morning st pattys': 1, 'morning afternoon graduation new years birthday': 1, 'summer afternoon thanksgiving': 1, 'fall summer': 1, 'afternoon party': 1})

# %%
from collections import defaultdict
cat_to_color = defaultdict(lambda: 'k')
cat_to_color.update({"winter":'g',
               "spring":'c',
               "summer":'r',
               "fall": "b"})
color_to_project = defaultdict(list)
for i in range(projected_docs.shape[0]):
    color_to_project[cat_to_color[''.join(documents[i][1])]].append(i)

# %%
plt.figure(figsize=(15,15))
for color, indices in color_to_project.items():
    indices = np.array(indices)
    plt.scatter(projected_docs[indices,0], projected_docs[indices,1],
                color = color)
plt.show()

# %%
docs_compressed = normalize(docs_compressed, axis = 1)
def closest_drinks(project_index_in, k = 5):
    sims = docs_compressed.dot(docs_compressed[project_index_in,:])
    asort = np.argsort(-sims)[:k+1]
    return [(documents[i][0],sims[i]/sims[asort[0]]) for i in asort[1:]]

# %%
for i in range(10):
    print(documents[i][0])
    for title, score in closest_projects(i):
        print("{}:{:.3f}".format(title[:40], score))
    print()
# Out:
# Vesper Cocktail
# Coconut Margarita:0.989
# Bordeaux Martini:0.848
# Banana Milk Shake:0.842
# Lychee Martini:0.811
# Japanese:0.809
#
# Tanning Bed Drink
# Poor Boy Tootsie Roll® Martini:0.807
# Kioki Coffee:0.786
# Vodka Russian:0.758
# Cranberry Cordial:0.752
# Hoot Mon Cocktail:0.744
#
# Spiced Rum Cream
# Bloody Scotsman:0.922
# Corpse Reviver #2:0.856
# The Oaxaca Old-Fashioned:0.735
# Bourbon And Elder:0.696
# Gauguin:0.652
#
# Saronno
# Planter's Punch No. 2:0.869
# Seventh H'Evan:0.740
# Coronation Cocktail:0.708
# Easy Mojitos:0.707
# Rum Runner:0.697
#
# Goat's Delight
# Rainy Portland (Warm Rum Drink):0.923
# Harvard Cooler:0.923
# Gables Collins:0.915
# Basil-Cucumber Mojito:0.912
# Trick or Treat Cocktail or Thankstini:0.906
#
# Cherry Flip
# General Harrison's Eggnog:0.987
# The Wink:0.984
# Harvest Moon:0.978
# Cowboy Margaritas:0.971
# Apricot Lady:0.938
#
# Uncommonly Clyde
# Mexicali Beer Margaritas:0.855
# Skinny Pina Colada:0.782
# Rio Fix:0.781
# Acapulco:0.756
# Tia-Maria:0.745
#
# Bermuda Highball
# Rhubarb-Infused 'Barbtini:0.981
# Level headed Cocktail:0.799
# Brass Monkey:0.780
# Coffee Flip:0.701
# The Deb (Peach-Basil Bourbon Smash) Cock:0.679
#
# Hemingway's Nog
# The Gibson:0.848
# Peppermint Margarita:0.830
# Strawberry Daiquiri:0.822
# Pimm's Cup Cocktail:0.804
# Gauguin:0.801
#
# Bahama Mama Celebration Drink
# Carre Reprise:0.902
# Cognac Coupling:0.747
# Watermelon Mint Punch:0.742
# Espresso Martini:0.731
# Cider Eggnog:0.721

# %%
drinkSimilarByName = dict()

for i in range(0, len(documents)):
    name = documents[i][0]
    drinkSimilarByName[name] = []
    for title, score in closest_drinks(i):
        if (score > 0.70):
            drinkSimilarByName[name].append({'name':title,'score':score})

print(drinkSimilarByName['Saronno'])
# Out:
# /Users/nate/Downloads/assignment5/venv/lib/python3.5/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# [{'name': "Planter's Punch No. 2", 'score': 0.8690680944364308}, {'name': "Seventh H'Evan", 'score': 0.7396968713069674}, {'name': 'Coronation Cocktail', 'score': 0.7078908426410161}, {'name': 'Easy Mojitos', 'score': 0.7070103012565433}]

# %%
with open('../app/static/related-drinks.json', 'w') as outfile:  
    json.dump(drinkSimilarByName, outfile)

# %%
drinkByName = dict()

with open('../app/static/drinks.json', 'r') as infile:  
    jsonData = json.load(infile)
    drinklst = jsonData['drinks']

for drink in drinklst:
    drinkByName[drink['name']] = drink

# %%
jsondata = {}
jsondata['drinks'] = []
for drink in drinkByName.values():
    try:
        ing = [(b +" " + a) for (a,b) in drink['ingredients'] if a != ""]
    except ValueError:
        ing = [a for a in drink['ingredients'] if a != ""]
        
    if 'instructions' in drink:
        drink['description'] = drink['instructions']
    
    jsondata['drinks'].append({
        'name' : drink['name'],
        'description' : drink['description'],
        'src' : drink['src'],
        'ingredients' : ing,
        'rating' : drink['rating'],
        'reviews' : drink.get('reviews', []),
        'categories' : drink.get('categories', []),
        'related' : drinkSimilarByName.get(drink['name'], [])
    })

# %%
with open('../app/static/drinks-with-related.json', 'w') as outfile:  
    json.dump(jsondata, outfile)
