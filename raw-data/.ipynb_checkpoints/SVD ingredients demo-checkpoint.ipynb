# %% [markdown]
# # Info/CS 4300: Language and Information
#
# ## SVD CLASS DEMO RECREATION FOR ROCKTAILS

# %%
from __future__ import print_function
import numpy as np
import json

# %% [markdown]
# ## Load the data

# %%
drinkByName = dict()

with open('../app/static/drinks.json', 'r') as infile:  
    jsonData = json.load(infile)
    drinklst = jsonData['drinks']
    for drink in drinklst:
        drink['ingredients'] = ' '.join(drink['ingredients'])
        drink['categories'] = ' '.join(drink['categories'])
#         drink['reviews'] = ' '.join(drink['reviews'])
    documents = [
        (x['name'],
         x['categories'],
         x['ingredients'])
                for x in drinklst]
    np.random.shuffle(documents)

# %%
print("Loaded {} documents".format(len(documents)))
print("Here is one of them:")
print(documents[0])
# Out:
# Loaded 2131 documents
# Here is one of them:
# ('Blood and Sand', 'halloween', '1/2 oz  Blended Scotch Whiskey 1/2 oz  cherry-flavored brandy 1/2 oz  Sweet Vermouth 1/2 oz  Orange juice')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words = 'english', max_df = .7,
                            min_df = 75)
my_matrix = vectorizer.fit_transform([x[2] for x in documents]).transpose()
# Out:
# /Users/nate/Downloads/assignment5/venv/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1039: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
print(type(my_matrix))
print(my_matrix.shape)
# Out:
# <class 'scipy.sparse.csc.csc_matrix'>
# (68, 2131)

# %%
from scipy.sparse.linalg import svds
u, s, v_trans = svds(my_matrix, k=50)

# %%
print(u.shape)
print(s.shape)
print(v_trans.shape)
# Out:
# (68, 50)
# (50,)
# (50, 2131)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(s[::-1])
plt.xlabel("Singular value number")
plt.ylabel("Singular value")
plt.show()

# %%
words_compressed, _, docs_compressed = svds(my_matrix, k=40)
docs_compressed = docs_compressed.transpose()

# %%
print(words_compressed.shape)
print(docs_compressed.shape)
# Out:
# (68, 40)
# (2131, 40)

# %%
word_to_index = vectorizer.vocabulary_
index_to_word = {i:t for t,i in word_to_index.items()}
print(words_compressed.shape)
# Out:
# (68, 40)

# %%
#row normalize
from sklearn.preprocessing import normalize
words_compressed = normalize(words_compressed, axis = 1)

# %%
def closest_words(word_in, k = 10):
    if word_in not in word_to_index: return "Not in vocab."
    sims = words_compressed.dot(words_compressed[word_to_index[word_in],:])
    asort = np.argsort(-sims)[:k+1]
    return [(index_to_word[i],sims[i]/sims[asort[0]]) for i in asort[1:]]

# %%
closest_words("vodka")
# Out:
# [('wedge', 0.24348682260133975),
#  ('cranberry', 0.11854932813007653),
#  ('vanilla', 0.09866259446295962),
#  ('cherry', 0.08556091009106377),
#  ('grenadine', 0.06472720871002824),
#  ('oz', 0.05543908897597367),
#  ('twist', 0.05188622730616699),
#  ('flavored', 0.04676972355969156),
#  ('creme', 0.041184916691738925),
#  ('ounce', 0.03263526689389111)]

# %%
print(list(word_to_index))
# Out:
# ['lime', 'dark', 'frozen', 'light', 'bitters', 'angostura', 'cranberry', 'tablespoons', 'schnapps', 'old', 'cream', 'sugar', 'grenadine', 'ice', 'juice', 'syrup', 'fluid', 'amaretto', 'coconut', 'dry', 'flavored', 'whiskey', 'sec', 'boston', 'cup', 'apple', 'cherry', 'creme', 'cups', 'gin', 'tequila', 'white', 'teaspoon', 'pineapple', 'orange', 'ounce', 'fresh', 'rum', 'vodka', 'ounces', 'ginger', 'simple', 'oz', 'liqueur', 'milk', 'vermouth', 'triple', 'cubes', 'lemon', 'jigger', 'powdered', 'wedge', 'tablespoon', 'bourbon', 'mr', 'twist', 'sweet', '12', 'vanilla', 'egg', 'tsp', 'water', 'coffee', 'salt', 'brandy', 'ground', 'soda', 'maraschino']

# %%
from sklearn.manifold import TSNE
tsne = TSNE(verbose=1)

# %%
print(docs_compressed.shape)
#we'll just take the first 5K documents, because TSNE is memory intensive!
subset = docs_compressed[:5000,:]
projected_docs = tsne.fit_transform(subset)
print(projected_docs.shape)
# Out:
# (2131, 40)
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2131
# [t-SNE] Computed conditional probabilities for sample 2000 / 2131
# [t-SNE] Computed conditional probabilities for sample 2131 / 2131
# [t-SNE] Mean sigma: 0.050870
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.253561
# [t-SNE] Error after 250 iterations: 1.253561
# (2131, 2)

# %%
plt.figure(figsize=(15,15))
plt.scatter(projected_docs[:,0],projected_docs[:,1])
plt.show()

# %%
from collections import Counter
t = [x[2] for x in documents]
cats = Counter(t)
print(cats)
# Out:
# Counter({'3/4 oz  Sweet Vermouth 3/4 oz  Dry Vermouth 3/4 oz  Gin': 3, '1 oz  Whole Egg 1 oz  Powdered Sugar 1 oz  Port 1 oz  Brandy': 2, '1 1/2 oz  Gin 3/4 oz  Dry Vermouth': 2, '1/2 oz  Juice of a Lemon 1/2 oz  Powdered Sugar 1 1/2 oz  Old Mr. Boston Dry Gin 1 oz  Creme Yvette': 2, '1 1/2 oz  Old Thompson Blended Whiskey 1 1/2 oz  Absinthe Substitute': 2, '1 1/2 oz  Dry Vermouth 1 1/2 oz  Sweet Vermouth 1 1/2 oz  Gin': 2, '1 1/2 oz  Mr. Boston Gin 3/4 oz  Dry Vermouth': 2, '1 1/2 oz  Gin 2 tsp superfine  Sugar 1 1/2 oz  Lemon juice 4 oz Chilled  Champagne 1  Orange 1  Maraschino cherry': 2, '1/2 oz  Gin 1/2 oz  Light Rum 1/2 oz  Vodka 1/2 oz  Hot Shot Tropical Fruit Liqueur 1 oz  7-Up 1 oz  each Cranberry Juice and orange juice': 2, '1 part  Creme de Cassis 5 parts  Champagne': 2, '1 2/3 oz  Gin 1/3 oz  Dry Vermouth': 2, '5 oz  Chilled Stout 5 oz  Chilled Champagne': 2, '1 oz  Grenadine 1/2 oz  Juice of a Lemon 2 oz  Swedish Punch': 2, '1 1/2 oz  Benedictine 1 oz  Whole Egg': 2, '1 1/2 oz  Light Rum 1 1/2 oz  Sweet Vermouth': 2, '1 oz  Gin 1/2 oz  White creme de menthe 1 oz  Forbidden Fruit': 1, 'ice cubes, or as needed 1 1/2 fluid ounces light rum 1/2 fluid ounce dry vermouth 1/2 fluid ounce orange curacao liqueur 1 dash grenadine syrup 1 twist orange peel': 1, '10 fluid ounces coconut flavored rum 6 fluid ounces pineapple juice 16 fluid ounces strawberry-flavored soda (such as Crush® Strawberry)': 1, '1 1/2 oz  Old Mr. Bo
               "fall": "b"})
color_to_project = defaultdict(list)
for i in range(projected_docs.shape[0]):
    color_to_project[cat_to_color[''.join(documents[i][1])]].append(i)

# %%
plt.figure(figsize=(15,15))
for color, indices in color_to_project.items():
    indices = np.array(indices)
    plt.scatter(projected_docs[indices,0], projected_docs[indices,1],
                color = color)
plt.show()

# %%
docs_compressed = normalize(docs_compressed, axis = 1)
def closest_projects(project_index_in, k = 5):
    sims = docs_compressed.dot(docs_compressed[project_index_in,:])
    asort = np.argsort(-sims)[:k+1]
    return [(documents[i][0],sims[i]/sims[asort[0]]) for i in asort[1:]]

# %%
for i in range(100):
    print(documents[i][0])
    for title, score in closest_projects(i):
        print("{}:{:.3f}".format(title[:40], score))
    print()
# Out:
# Blood and Sand
# Irish Spring:0.864
# Texas Rattlesnake:0.709
# Fratelli Cocktail:0.681
# Aquarius:0.678
# Stone Sour:0.677
#
# Savannah
# Creme de Gin Cocktail:0.958
# Poppy Cocktail:0.742
# Virgin:0.737
# Suissesse Cocktail:0.710
# Dolores:0.709
#
# Beer Buster
# Beer Buster:1.000
# Kool-Aid Slammer:1.000
# Frisky Witch:1.000
# Dreamy Dorini Smoking Martini:0.980
# Champagne Flamingo:0.980
#
# Green Dragon Cocktail
# Green Opal Cocktail:0.948
# Barbary Coast Cocktail:0.940
# K.C.B. Cocktail:0.937
# Fallen Angel Cocktail:0.933
# Vodka Grasshopper Cocktail:0.922
#
# Mimosa
# Mimosa:1.000
# Bucks Fizz (Mimosa):1.000
# Mudslinger:0.967
# Berry Deadly:0.967
# Holloween Punch:0.967
#
# Pacific Sunshine
# Tequila Sour:0.755
# Oldest Temptation:0.754
# Champs Elysees Cocktail:0.754
# High Plains Drifter No. 1:0.749
# Tequila Old-Fashioned:0.731
#
# Porto flip
# Baltimore Bracer:0.870
# Pousse L'Amour:0.744
# Kiss the Boys Goodbye:0.743
# Grapefruit Nog:0.720
# Sol Y Sombra:0.627
#
# The Cinquecento
# Pickled Pink:0.879
# Bravo:0.755
# El Profesor:0.731
# Sargasso:0.720
# L'italienne:0.719
#
# Alfie Cocktail
# Lemon Crush:0.742
# Hawaiian Cocktail:0.704
# Hawaiin Cocktail:0.701
# Waikiki Beachcomber:0.701
# After Supper Cocktail:0.693
#
# Caf_ di Amaretto
# Cafe di Saronno:0.995
# Tennesee Mud:0.906
# Almond Chocolate Coffee:0.870
# Saronno Mist:0.693
# Jackhammer:0.689
#
# Blue Hawaiian Cocktail
# Pina Colada IV:0.852
# Easy Pina Colada Punch:0.767
# Pink Pineapple Dream:0.738
# Chi Chi:0.735
# Singapore Sling Cocktail:0.722
#
# Eggnog I
# Vitamix® Eggnog:0.824
# Traditional Eggnog:0.815
# Luscious Eggnog:0.767
# Eggnog Blend:0.742
# Spoonable Eggnog:0.736
#
# Dolores
# Aunt Jemima:0.731
# Stinger:0.730
# Fantasio Cocktail:0.725
# Baltimore Bracer:0.720
# Savannah:0.709
#
# Coquito
# Ponche de Coquito:0.914
# Tropical Coquito:0.878
# Coconut Rum Cream:0.869
# Christmas Creamy Eggnog:0.837
# Kamikaze Cocktail:0.798
# Long Island Iced Tea Cocktail:0.789
#
# Absinthe #2
# Espresso Martini:0.812
# Irish Russian:0.746
# 410 Gone:0.692
# Vodka Russian:0.692
# The Groupie:0.628
#
# Coconut Margaritas
# Kim's Peach Margarita:0.765
# Frozen Avocado Margaritas:0.688
# Banana Margaritas:0.651
# Banana Colada:0.640
# Magnificent Frozen Mango Margaritas:0.639
#
# Waterbury Cocktail
# Ruby Fizz:0.831
# Bird-of-Paradise Fizz:0.831
# Morning Glory Fizz:0.764
# Chocolate Daisy:0.755
# Hot Brandy Flip:0.750
#
# El Presidente Cocktail
# Autumn Sunshine Cocktail:0.613
# California Sunset:0.584
# Summer Delight:0.534
# Shark Bite Cocktail:0.528
# Red Death Cocktail:0.518
#
# Phoebe Snow Cocktail
# Praire Oyster Cocktail:0.982
# Widow's Kiss Cocktail:0.919
# Golden Slipper Cocktail:0.904
# Hop Toad Cocktail :0.901
# Cherry Blossom Cocktail:0.895
#
# Frozen Strawberry Margarita
# Ultimate Frozen Strawberry Margarita:0.941
# Margaritas:0.871
# Yummy Margaritas:0.811
# Basic Margarita:0.801
# Magnificent Frozen Mango Margaritas:0.796
#
# Aged Eggnog Cocktail
# Pumpkin Cocktail:0.885
# Green Gecko:0.873
# Dragon:0.871
# The Shaner Bill:0.828
# Austin Margarita (aka Mexican Martini):0.811
#
# Vodka and Apple Juice
# Avalon:0.894
# Apple Pie with A Crust:0.844
# Ziemes Martini Apfelsaft:0.824
# Apple Berry Smoothie:0.808
# Red Apple:0.808
#
# Spanish Town Cocktail
# White Lily Cocktail:0.878
# X.Y.Z. Cocktail:0.824
# Oh, Gosh!:0.816
# Casa Blanca:0.808
# Between The Sheets:0.798
#
# Frankenjack Cocktail
# Fog Horn:0.790
# Dragonfly:0.681
# Webster Cocktail:0.670
# Mamie's Sister:0.669
# Snyder:0.647
#
# Dillatini Cocktail
# Martini :1.000
# Dillatini Cocktail:1.000
# Queen Elizabeth Cocktail:0.972
# Blood Bronx Cocktail:0.926
# Cabaret Cocktail:0.922
#
# Hot Lemonade
# Reunion Rum Punch:0.638
# Creme de Menthe:0.620
# Homemade Old Fashioned Mix:0.605
# Lassi - Sweet:0.585
# Holiday Hot Buttered Rum:0.583
#
# Rye Whiskey Cocktail
# Whiskey Milk Punch:0.889
# Dixie Julep:0.872
# Whiskey Toddy (cold):0.764
# Cablegram Highball:0.757
# Absinthe Drip Cocktail:0.748
#
# Tequini
# Rosita:0.786
# Yale Cocktail:0.780
# Sargasso:0.761
# Palmetto Cocktail:0.746
# El Presidente Cocktail No. 2:0.746
#
# Mai Tai Cocktail
# Storm of the Century Hurricane:0.870
# Sunset Rum Punch:0.832
# Texas Hurricane:0.767
# California Sunset:0.761
# Blue Island Ice Tea:0.754
#
# The Blood Orange
# Mango Orange Smoothie:0.787
# Tabby Cat:0.761
# Budget Jungle Juice for a Crowd:0.713
# 50/50:0.697
# Screwdriver:0.691
#
# Chai Martini
# Chocolate Martini a la Laren:0.819
# Pomegranate Martini II:0.810
# Scorpion Bowl:0.808
# Chocolate Martini Cocktail:0.802
# Dill Pickle Martini:0.795
#
# Rum Toddy (Cold)
# Rum Cobbler:0.788
# Rum Cooler:0.709
# Goat's Delight:0.674
# Bull's Milk:0.662
# Quaker's Cocktail:0.648
#
# Hillbilly Punch
# The South Mission Mango:0.648
# Sparkling Sex on the Beach:0.634
# Grenade Launcher:0.567
# Cranberry Rum Punch:0.565
# Blackberry Liqueur:0.548
#
# Golden Frappe
# Yellowjacket:0.654
# Mimosa:0.650
# Bucks Fizz:0.650
# Bucks Fizz (Mimosa):0.650
# Verboten:0.648
#
# Irish Whisky
# Irish Whisky Cocktail:0.982
# Irish Whiskey Cocktail:0.744
# Deshler:0.691
# Blarney Stone Cocktail:0.675
# Fancy Brandy Cocktail:0.650
#
# Hemingway Special
# Zima Blaster:0.675
# Zimadori Zinger:0.675
# Floridita No. 3:0.594
# Aviation:0.582
# Jungle Juice for a Crowd:0.563
#
# The Groupie
# Bordeaux Cocktail:0.768
# Stockholm 75:0.708
# Lemon Crush:0.685
# Lemon Drop:0.667
# Peach Iced Tea:0.653
#
# Cara Sposa
# Cafe Savoy:0.747
# Spanish Coffee:0.737
# Kioki Coffee:0.727
# Creme De Cafe:0.693
# After Supper Cocktail:0.679
#
# Mocha Express
# Mocha-Berry:0.946
# Black Russian:0.945
# Black Magic:0.831
# Jamaica Coffee:0.806
# Priority Cocktail:0.778
#
# Bluebird
# East India Cocktail No. 1:0.747
# Brandy Crusta Cocktail:0.673
# Blue Bird:0.607
# Melon Cocktail:0.605
# Blarney Stone Cocktail:0.579
#
# Mai Tai
# Fair-and-Warmer Cocktail:0.803
# Spanish Town Cocktail:0.688
# Long Island Iced Tea:0.668
# Casa Blanca:0.644
# 3-Mile Long Island Iced Tea:0.613
#
# Velvet Hammer No. 2
# Grasshopper:0.944
# Alexander:0.902
# Alexander Cocktail No. 1:0.902
# Alexander Cocktail No. 2:0.892
# Hyatt's Jamaican Banana:0.889
#
# Mulled Wine
# Mojiteas:0.732
# Lassi - Mango:0.691
# Mangosteen Margarita:0.635
# Lassi - Sweet:0.630
# Amaretto Liqueur:0.606
#
# Red Apple Martini
# Moose River Hummers:0.908
# Green Gecko:0.840
# Buttery Nipple:0.821
# Fricken Yummy:0.820
# Purple People Eater:0.813
#
# Canadian Cocktail
# Fancy Brandy:0.941
# The Wink:0.889
# Jack Maples:0.816
# Americana:0.782
# Fancy Whiskey:0.740
#
# The Summer Of Love
# Le Paradini:0.786
# Zipperhead:0.647
# The Blood Orange:0.637
# The Jamaican Ten Speed:0.612
# Handball Cooler:0.590
#
# Purple Pancho
# Viva Villa:0.852
# Satin Sheets:0.830
# Sloe Tequila:0.752
# Cactus Berry:0.747
# Bianca:0.740
#
# Frappé
# Tia-Maria:0.759
# Iced Coffee:0.738
# Castillian Hot Chocolate:0.721
# Iced Coffee Fillip:0.710
# Egg Nog - Healthy:0.705
#
# Radler
# Owen's Grandmother's Revenge:0.954
# Miami Vice:0.918
# Wonderful Margaritas:0.904
# Strawberry Beer Margaritas:0.889
# Beer Margaritas:0.884
#
# Love Cocktail
# Ping-Pong Cocktail:0.974
# North Pole Cocktail:0.870
# Cornell Cocktail:0.870
# Doctor Cook:0.870
# Kiss the Boys Goodbye:0.868
#
# Port Wine Cobbler
# Gin Fizz:0.774
# Adam Sunrise:0.764
# Gin Toddy:0.732
# Gin Squirt:0.703
# Rum Toddy:0.668
#
# Polonaise
# French Quarter:0.813
# What The Hell:0.799
# Why Not?:0.799
# Favourite Cocktail:0.799
# Favorite Cocktail:0.799
#
# Blonde Bobbie
# Buttery Nipple:0.934
# Dr. Horrible:0.903
# Eggnog Russian:0.839
# Snowflake Cocktail:0.839
# Pumpkin Spice Martini:0.827
#
# Western Rose Cocktail
# Thanksgiving Special Cocktail:1.000
# K.C.B. Cocktail:0.917
# Green Opal Cocktail:0.883
# Napoleon Cocktail:0.878
# Thunderclap Cocktail:0.877
#
# Bahama Breeze
# Summer Delight:0.888
# Bahama Mama:0.832
# Twisted Stripper:0.819
# Grateful Dead Cocktail:0.759
# Long Island Iced Tea Cocktail:0.753
#
# Ramos Fizz
# Scotch Bird Flyer:0.873
# Pink Rose Fizz:0.856
# Lady Love Fizz:0.856
# Derby Fizz:0.797
# New Orleans Gin Fizz:0.782
#
# Purple Passion
# Victory Collins:0.823
# Katana:0.767
# Vodka Sour:0.745
# Bloody Scotsman:0.744
# Vodka Gimlet:0.744
#
# Bruce's Puce
# Alice Cocktail:0.731
# Grenadine Rickey:0.636
# Moranguito:0.629
# Dirty Nipple:0.625
# B-52:0.625
#
# Champs Elysees Cocktail
# The Holy Roller:0.775
# Jack Maples:0.773
# Japanese:0.771
# Fancy Brandy:0.768
# Pacific Sunshine:0.754
#
# Coconut Rum Cream
# Coquito:0.869
# Puerto Rican Coquito:0.866
# Spiced Rum Cream:0.829
# Rum-Spiked Horchata:0.817
# Ponche de Coquito:0.814
#
# Malibu Twister
# Bleeding Surgeon:0.810
# Harvest Nectar:0.756
# Prohibition Punch:0.749
# Sex on the Beach:0.739
# Sea breeze:0.739
#
# Pomosa
# Ripley's Bloody Mary Mix for Canning:0.918
# Homemade Bloody Mary Mix:0.908
# World's Best Bloody Mary Mix:0.877
# New Orleans Creole Eggnog:0.844
# Dani's Butt Kickin' Bloody Mary Mix:0.837
#
# Sex on the Beach III
# Tokyo Rose:0.804
# Prom Night:0.783
# Casa Marina:0.775
# Absolute Stress:0.701
# Pink Penocha:0.700
#
# Alice Cocktail
# Afterglow:0.889
# Arizona Twister:0.817
# Bora Bora:0.759
# Space Odyssey:0.745
# Bruce's Puce:0.731
#
# Coco Loco
# Dave Matthews:0.744
# Bahama Mama:0.729
# Bahama Breeze:0.728
# Grilled Pineapple Mai Tai:0.725
# Twisted Stripper:0.722
#
# Algonquin
# Back Porch Swizzle:0.780
# Manhattan Cocktail (dry):0.766
# Chancellor Cocktail:0.751
# Mary Garden Cocktail:0.696
# Antoine Special:0.696
#
# Scotch Cobbler
# Valencia Cocktail:0.816
# Apricot punch:0.784
# Bull's Eye:0.733
# Sol Y Sombra:0.733
# Jelly Bean:0.733
#
# Pink Panty Pulldowns
# Jello shots:0.903
# Blackberry Liqueur:0.853
# Adult Watermelon for BBQ's:0.841
# Grand Margarita:0.811
# Allie's Espresso Kahlua® Liqueur:0.809
#
# Red Apple
# Vodka and Apple Juice:0.808
# Avalon:0.767
# Depth Bomb:0.732
# Apple Pie with A Crust:0.685
# Golden Eclipse:0.668
#
# Hippie Juice
# Berry Shooters:0.656
# Flatiron Martini:0.640
# Alfie Cocktail:0.610
# Perfect Pitcher of Pink Raspberry Cosmop:0.594
# Bahama Mama Celebration Drink:0.592
#
# Rum Toddy
# Rum Old-fashioned:0.916
# Gin Toddy:0.887
# Bourbon Sling:0.848
# Sazerac:0.836
# Kool First Aid:0.784
#
# Cape Cod and White Zinfandel
# Madras Cocktail:0.670
# Baybreeze Cocktail:0.667
# Cape Breeze:0.648
# Cedarwood:0.638
# Peach Cosmo:0.625
#
# Don's Friend Tonja's Cousin Toni's Boyfriend's Grandmother's Eggnog
# Eggnog Blend:0.860
# Spoonable Eggnog:0.752
# Avalanche:0.734
# Dirty Nipple:0.734
# 747:0.734
#
# Best Strawberry Daiquiri
# Sheila's Perfect Sangria:0.787
# Rachel's Rose Sangria:0.752
# Fruit Flip-Flop:0.733
# Sangria #1:0.728
# Watermelon Mint Punch:0.716
#
# Paradise
# Scotch Cobbler:0.727
# Apricot Cocktail:0.724
# Valencia Cocktail:0.699
# Bulldog Highballl:0.697
# Apricot punch:0.663
#
# Grateful Dead Cocktail
# The REAL Long Island Iced Tea:0.850
# Long Island Iced Tea Cocktail:0.821
# Blue Island Ice Tea:0.817
# Texas Tea I:0.799
# Storm of the Century Hurricane:0.795
#
# Rum Sour
# Van Vleet:0.939
# Rum Fix:0.921
# Planter's Cocktail:0.911
# Daiquiri:0.843
# Rum Daisy:0.813
#
# Sunburn
# Mandarine Mist:0.920
# Applejack:0.899
# Bob Marley:0.899
# Absolut Sex:0.865
# Mandarine Sour:0.859
#
# Negroni Cocktail II
# Blue Sky Martini:0.824
# The REAL Long Island Iced Tea:0.823
# Blue Island Ice Tea:0.784
# Peachy Keen Long Island Iced Tea:0.783
# Mrs. Baxton's Long Island Iced Tea:0.734
#
# Christmas Creamy Eggnog
# Ponche de Coquito:0.847
# Sweet Creme de Vie:0.837
# Coquito:0.837
# Coconut Coquito:0.833
# Tropical Coquito:0.811
#
# Spiced Pumpkin Cider Martini
# Fall Festive-tini:0.663
# Key Lime Pie:0.658
# Summer Hummer:0.603
# Chai Martini:0.566
# Candy Red Apple Martini:0.562
#
# Melon Cocktail
# Grapefruit Cocktail:0.897
# Blue Devil Cocktail:0.883
# Opera Cocktail:0.837
# Spring Feeling Cocktail:0.778
# Biffy Cocktail:0.778
#
# Halloween Candy Corn Jell-O® Shots
# Tainted Fruit Shots:0.666
# The South Mission Mango:0.586
# Caramel Liqueur:0.573
# Electric Lightning:0.566
# Jello shots:0.533

# %%
print(documents[0])
# Out:
# ('Apple Pie Cocktail', ['fall', 'thanksgiving'], 'Shake with ice and strain into cocktail glass. ', [])
